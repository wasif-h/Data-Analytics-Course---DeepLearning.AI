# %% [markdown]
# link of original Dataset and question - https://docs.google.com/spreadsheets/d/18PBqO9KN-oG_ABZ4ABae7nb6wP4yVlcfPI83k-xZfx0/copy?usp=sharing

# %%
import numpy as numpy
import pandas as pd

# %%
df = pd.read_csv("Video_game_market.csv")
print(df.info())
display(df.sample(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1568 non-null   object
#  1   Platform      1568 non-null   object
#  2   Genre         1568 non-null   object
#  3   Publisher     1568 non-null   object
#  4   NA_Sales      469 non-null    float64
#  5   EU_Sales      234 non-null    float64
#  6   JP_Sales      282 non-null    float64
#  7   Other_Sales   508 non-null    float64
#  8   Global_Sales  660 non-null    float64
#  9   Release_Date  1568 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 122.6+ KB
# None
#                                    Name Platform             Genre  \
# 552       ACA NEOGEO SAMURAI SHODOWN IV     XOne          Fighting
# 338                                Moss      PS4         Adventure
# 977              Urban Trial Playground       NS            Racing
# ...
